# %%
from bot import telegramBot

# %%
bots = [telegramBot.cires_bot(),
        telegramBot.test_bot(),
        telegramBot.myassistant_bot()]

# %%
updates = bots[0].get_updates()
updates
# Out:
# {'ok': True,
#  'result': [{'update_id': 159395017,
#    'message': {'message_id': 1073,
#     'from': {'id': 1316362961,
#      'is_bot': False,
#      'first_name': 'Daniel',
#      'last_name': 'Ibarrola',
#      'language_code': 'en'},
#     'chat': {'id': -713981844,
#      'title': 'Información CIRES',
#      'type': 'group',
#      'all_members_are_administrators': True},
#     'date': 1638371262,
#     'new_chat_participant': {'id': 1587037174,
#      'is_bot': True,
#      'first_name': 'ciresBot',
#      'username': 'cires_bot'},
#     'new_chat_member': {'id': 1587037174,
#      'is_bot': True,
#      'first_name': 'ciresBot',
#      'username': 'cires_bot'},
#     'new_chat_members': [{'id': 1587037174,
#       'is_bot': True,
#       'first_name': 'ciresBot',
#       'username': 'cires_bot'}]}},
#   {'update_id': 159395018,
#    'my_chat_member': {'chat': {'id': -713981844,
#      'title': 'Información CIRES',
#      'type': 'group',
#      'all_members_are_administrators': True},
#     'from': {'id': 1316362961,
#      'is_bot': False,
#      'first_name': 'Daniel',
#      'last_name': 'Ibarrola',
#      'language_code': 'en'},
#     'date': 1638371262,
#     'old_chat_member': {'user': {'id': 1587037174,
#       'is_bot': True,
#       'first_name': 'ciresBot',
#       'username': 'cires_bot'},
#      'status': 'left'},
#     'new_chat_member': {'user': {'id': 1587037174,
#       'is_bot': True,
#       'first_name': 'ciresBot',
#       'username': 'cires_bot'},
#      'status': 'member'}}}]}

# %%
for bot in bots:
    print(f"Created bot with name {bot.name} and token {bot.token}")
    print(f"Base url for this bot is {bot.base_url}")
    print(bot.groups)
    print("\n\n")
# Out:
# Created bot with name cires_bot and token 1587037174:AAFGzAMHQOGKsmtBGOXfG7VdhkmWSiiaYaQ
# Base url for this bot is https://api.telegram.org/bot1587037174:AAFGzAMHQOGKsmtBGOXfG7VdhkmWSiiaYaQ/
# {'Información CIRES': -713981844}
#
#
#
# Created bot with name test_bot and token 1214960317:AAEgnZDdxJmWW3ydxmmIM5Uw75niQ_AXydQ
# Base url for this bot is https://api.telegram.org/bot1214960317:AAEgnZDdxJmWW3ydxmmIM5Uw75niQ_AXydQ/
# {'RACM servicio': -1001139087723, 'Grupo_prueba2': -373994761}
#
#
#
# Created bot with name PulpoalaDiabla_bot and token 1752937658:AAH4bwdX-xoLCSO1Zgq-NZh1vHAUH0P6HpI
# Base url for this bot is https://api.telegram.org/bot1752937658:AAH4bwdX-xoLCSO1Zgq-NZh1vHAUH0P6HpI/
# {}
